# %%
# !pip install neo4j-graphrag neo4j openai

# %%
import os
# os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY"
os.environ["OPENAI_API_KEY"] = "sk-yt5OA2_9g-wl7WHsWYPyrzWFm5IBAVhYSYATdmsy2RT3BlbkFJYbdBlbdcasGP5nAjVYbpKi8LeMV1UIoPYCyhVVWnsA"
